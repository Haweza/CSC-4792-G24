# %%
# %pip install pdfplumber
# Out:
# Requirement already satisfied: pdfplumber in C:\Users\hp\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (0.11.10)
# Requirement already satisfied: pdfminer.six==20260107 in C:\Users\hp\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pdfplumber) (20260107)
# Requirement already satisfied: Pillow>=12.2.0 in C:\Users\hp\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pdfplumber) (12.3.0)
# Requirement already satisfied: pypdfium2>=5.9.0 in C:\Users\hp\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pdfplumber) (5.13.0)
# Requirement already satisfied: charset-normalizer>=2.0.0 in C:\Users\hp\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pdfminer.six==20260107->pdfplumber) (3.4.9)
# Requirement already satisfied: cryptography>=36.0.0 in C:\Users\hp\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pdfminer.six==20260107->pdfplumber) (50.0.1)
# Requirement already satisfied: cffi>=2.0.0 in C:\Users\hp\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from cryptography>=36.0.0->pdfminer.six==20260107->pdfplumber) (2.1.1)
# Requirement already satisfied: pycparser in C:\Users\hp\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from cffi>=2.0.0->cryptography>=36.0.0->pdfminer.six==20260107->pdfplumber) (3.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.0.1 -> 26.2.1
# [notice] To update, run: C:\Users\hp\AppData\Local\Python\pythoncore-3.14-64\python.exe -m pip install --upgrade pip

# %%
import pdfplumber

# %%
import pandas
# Out:
# ------------------------------------------------------------------------
# ModuleNotFoundError                    Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import pandas
#
# ModuleNotFoundError: No module named 'pandas'

# %%
# %pip install requests pandas
# Out:
# Requirement already satisfied: requests in C:\Users\hp\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (2.34.2)
# Collecting pandas
#   Downloading pandas-3.0.5-cp314-cp314-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\hp\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\hp\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\hp\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in C:\Users\hp\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests) (2026.7.22)
# Requirement already satisfied: numpy>=2.3.3 in C:\Users\hp\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pandas) (2.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\hp\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\hp\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pandas) (2026.3)
# Requirement already satisfied: six>=1.5 in C:\Users\hp\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-3.0.5-cp314-cp314-win_amd64.whl (10.0 MB)
#    ---------------------------------------- 0.0/10.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.0 MB ? eta -:--:--
#    - -------------------------------------- 0.3/10.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/10.0 MB 1.2 MB/s eta 0:00:08
#    ----- ---------------------------------- 1.3/10.0 MB 2.3 MB/s eta 0:00:04
#    ------ --------------------------------- 1.6/10.0 MB 2.5 MB/s eta 0:00:04
#    -------------- ------------------------- 3.7/10.0 MB 4.0 MB/s eta 0:00:02
#    ---------------- ----------------------- 4.2/10.0 MB 3.7 MB/s eta 0:00:02
#    ----------------- ---------------------- 4.5/10.0 MB 3.8 MB/s eta 0:00:02
#    ----------------------- ---------------- 5.8/10.0 MB 3.6 MB/s eta 0:00:02
#    ---------------------------- ----------- 7.1/10.0 MB 4.0 MB/s eta 0:00:01
#    ------------------------------- -------- 7.9/10.0 MB 4.0 MB/s eta 0:00:01
#    ------------------------------------- -- 9.4/10.0 MB 4.3 MB/s eta 0:00:01
#    -------------------------------------- - 9.7/10.0 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------------- 10.0/10.0 MB 3.8 MB/s  0:00:03
# Installing collected packages: pandas
# Successfully installed pandas-3.0.5
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.0.1 -> 26.2.1
# [notice] To update, run: C:\Users\hp\AppData\Local\Python\pythoncore-3.14-64\python.exe -m pip install --upgrade pip

# %%
import requests
import pdfplumber
import pandas as pd

# %%
print("All libraries installed successfully!")
# Out:
# All libraries installed successfully!

# %%
import requests
print("requests: OK")

import pdfplumber
print("pdfplumber: OK")

import pandas as pd
print("pandas: OK")
# Out:
# requests: OK
# pdfplumber: OK
# pandas: OK

# %%
url = "https://www.chisambacouncil.gov.zm/wp-content/uploads/2025/12/2024-CDF-APPROVED-COMMUNITY-PROJECTS-CHISAMBA-1-2.pdf"
response = requests.get(url, verify=False)
print(response.status_code)
print(len(response.content))
# Out:
# C:\Users\hp\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\urllib3\connectionpool.py:1110: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.chisambacouncil.gov.zm'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# 200
# 414535

# %%
with open( "Chisamba2024.pdf","wb") as f:
    f.write(response.content)
print("PDF saved Successfully")
# Out:
# PDF saved Successfully

# %%
with pdfplumber.open("chisamba2024.pdf") as pdf:
    for page in pdf.pages:
        tables = page.extract_tables()
        print(tables)
# Out:
# [[['SN', 'PROJECT NAME', 'PROJECT DESCRIPTION', 'WARD', 'ZONE', 'SECTOR OF\nPROJECT'], ['1', 'PROCUREMENT OF AMBULANCE FOR CHISAMBA\nCONSTITUENCY', 'PROCUREMENT OF AMBULANCE FOR\nCHISAMBA CONSTITUENCY', 'ALL', 'ALL', 'HEALTH'], ['2', "MOTOR BIKE FOR THE CHIEF'S RETAINER FOR HRH\nCHIEF CHAMUKA", "MOTOR BIKE FOR THE CHIEF'S\nRETAINER FOR HRH CHIEF CHAMUKA", 'CHAMUKA', 'CHAMUKA', 'TRANSPORT'], ['3', 'CONSTRUCTION OF MATERNITY ANNEX AT\nLOMBWA HEALTH POST', 'CONSTRUCTION OF MATERNITY ANNEX\nAT LOMBWA HEALTH POST', 'MULUNGUSHI', 'LOMBWA', 'HEALTH'], ['4', 'CONSTRUCTION OF MATERNITY ANNEX AT\nKABANGA HEALTH POST', 'CONSTRUCTION OF MATERNITY ANNEX\nAT KABANGA HEALTH POST', 'CHIKONKOMENE', 'KABANGA', 'HEALTH'], ['5', 'CONSTRUCTION OF MATERNITY ANNEX AT MISWA\nHEALTH POST', 'CONSTRUCTION OF MATERNITY ANNEX\nAT MISWA HEALTH POST', 'MISWA', '', 'HEALTH'], ['6', 'CONSTRUCTION OF MATERNITY ANNEX AT\nMUPELEKESE HEALTH POST', 'CONSTRUCTION OF MATERNITY ANNEX\nAT MUPELEKESE HEALTH POST', 'MWAPULA', 'MUPELEKESE', 'HEALTH'], ['7', 'CONSTRUCTION OF MATERNITY ANNEX AT\nLUKOSHI HEALTH POST', 'CONSTRUCTION OF MATERNITY ANNEX\nAT LUKOSHI HEALTH POST', 'MUTENGA', 'LUKOSHI', 'HEALTH'], ['8', 'CONSTRUCTION OF MATERNITY ANNEX AT\nKAMANO HEALTH POST', 'CONSTRUCTION OF MATERNITY ANNEX\nAT KAMANO HEALTH POST', 'KAMANO', 'KAMANO', 'HEALTH'], ['9', "CONSTRUCTION OF MATERNITY ANNEX AT\nMONANG'OMBE", "CONSTRUCTION OF MATERNITY ANNEX\nAT MONANG'OMBE", 'MONAGOMBE', 'MONAGOMBE', 'HEALTH'], ['10', 'CONSTRUCTION OF STAFF HOUSE AT MUSWISHI\nHEALTH POST', 'CONSTRUCTION OF STAFF HOUSE AT\nMUSWISHI HEALTH POST', 'MUSWISHI', 'MUSWISHI', 'HEALTH'], ['11', 'CONSTRUCTION OF ABLUTION BLOCK AT\nMUSWISHI HEALTH POST', 'CONSTRUCTION OF ABLUTION BLOCK\nAT MUSWISHI HEALTH POST', 'MUSWISHI', 'MUSWISHI', 'HEALTH'], ['12', 'PROCUREMENT OF A TIPPER TRUCK', 'PROCUREMENT OF A TIPPER TRUCK', 'ALL', 'ALL', 'ROAD\nDEVELOPMENT'], ['13', 'PROCUREMENT OF CULVERTS, FUELS, OILS,\nMAINTENANCE OF EQUIPMENT FOR ROAD WORKS', 'PROCUREMENT OF CULVERTS, FUELS,\nOILS, MAINTENANCE OF EQUIPMENT\nFOR ROAD WORKS', 'ALL', 'ALL', 'ROAD\nDEVELOPMENT']]]
# [[['SN', 'PROJECT NAME', 'PROJECT DESCRIPTION', 'WARD', 'ZONE', 'SECTOR OF\nPROJECT'], ['1', "TOP UP ON REHABILITATION OF TEACHERS' STAFF\nHOUSES AT KAPUTI PRIMARY SCHOOL", "TOP UP ON REHABILITATION OF\nTEACHERS' STAFF HOUSES AT KAPUTI\nPRIMARY SCHOOL", 'CHAMUKA', 'KAPUTI', 'EDUCATION'], ['2', 'REHABILITATION OF 1X3 CLASSROOM BLOCK AT\nMOMBOSHI SCHOOL', 'REHABILITATION OF 1X3 CLASSROOM\nBLOCK AT MOMBOSHI SCHOOL', 'MUTENGA', 'MOMBOSHI', 'EDUCATION'], ['3', 'REHABILITATION OF TEACHER’S STAFF HOUSE AT\nMOMBOSHI SCHOOL', 'REHABILITATION OF TEACHER’S STAFF\nHOUSE AT MOMBOSHI SCHOOL', 'MUTENGA', 'MOMBOSHI', 'EDUCATION'], ['4', 'REHABILITATION OF KASAVASA ROAD', 'REHABILITATION OF KASAVASA ROAD', 'MISWA/MUTENGA', 'MISWA/MUTENGA', 'INFRASTRUCTURE'], ['5', 'CONSTRUCTION OF VIP TOILET', 'CONSTRUCTION OF VIP TOILET AT\nBOMBWE PRIMARY SCHOOL', 'MULUNGUSHI', 'BOMBWE', 'EDUCATION']]]

# %%
import pandas as pd
all_rows = []
with pdfplumber.open("Chisamba2024.pdf") as pdf:
    for page in pdf.pages:
        table = page.extract_table()
        all_rows.extend(table)
df = pd.DataFrame(all_rows[1:], columns=all_rows[0])
df
# Out:
#     SN                                       PROJECT NAME  \
# 0    1  PROCUREMENT OF AMBULANCE FOR CHISAMBA\nCONSTIT...
# 1    2  MOTOR BIKE FOR THE CHIEF'S RETAINER FOR HRH\nC...
# 2    3  CONSTRUCTION OF MATERNITY ANNEX AT\nLOMBWA HEA...
# 3    4  CONSTRUCTION OF MATERNITY ANNEX AT\nKABANGA HE...
# 4    5  CONSTRUCTION OF MATERNITY ANNEX AT MISWA\nHEAL...
# 5    6  CONSTRUCTION OF MATERNITY ANNEX AT\nMUPELEKESE...
# 6    7  CONSTRUCTION OF MATERNITY ANNEX AT\nLUKOSHI HE...
# 7    8  CONSTRUCTION OF MATERNITY ANNEX AT\nKAMANO HEA...
# 8    9    CONSTRUCTION OF MATERNITY ANNEX AT\nMONANG'OMBE
# 9   10  CONSTRUCTION OF STAFF HOUSE AT MUSWISHI\nHEALT...
# 10  11  CONSTRUCTION OF ABLUTION BLOCK AT\nMUSWISHI HE...
# 11  12                      PROCUREMENT OF A TIPPER TRUCK
# 12  13  PROCUREMENT OF CULVERTS, FUELS, OILS,\nMAINTEN...
# 13  SN                                       PROJECT NAME
# 14   1  TOP UP ON REHABILITATION OF TEACHERS' STAFF\nH...
# 15   2  REHABILITATION OF 1X3 CLASSROOM BLOCK AT\nMOMB...
# 16   3  REHABILITATION OF TEACHER’S STAFF HOUSE AT\nMO...
# 17   4                    REHABILITATION OF KASAVASA ROAD
# 18   5                         CONSTRUCTION OF VIP TOILET
#
#                                   PROJECT DESCRIPTION           WARD  \
# 0   PROCUREMENT OF AMBULANCE FOR\nCHISAMBA CONSTIT...            ALL
# 1   MOTOR BIKE FOR THE CHIEF'S\nRETAINER FOR HRH C...        CHAMUKA
# 2   CONSTRUCTION OF MATERNITY ANNEX\nAT LOMBWA HEA...     MULUNGUSHI
# 3   CONSTRUCTION OF MATERNITY ANNEX\nAT KABANGA HE...   CHIKONKOMENE
# 4   CONSTRUCTION OF MATERNITY ANNEX\nAT MISWA HEAL...          MISWA
# 5   CONSTRUCTION OF MATERNITY ANNEX\nAT MUPELEKESE...        MWAPULA
# 6   CONSTRUCTION OF MATERNITY ANNEX\nAT LUKOSHI HE...        MUTENGA
# 7   CONSTRUCTION OF MATERNITY ANNEX\nAT KAMANO HEA...         KAMANO
# 8     CONSTRUCTION OF MATERNITY ANNEX\nAT MONANG'OMBE      MONAGOMBE
# 9   CONSTRUCTION OF STAFF HOUSE AT\nMUSWISHI HEALT...       MUSWISHI
# 10  CONSTRUCTION OF ABLUTION BLOCK\nAT MUSWISHI HE...       MUSWISHI
# 11                      PROCUREMENT OF A TIPPER TRUCK            ALL
# 12  PROCUREMENT OF CULVERTS, FUELS,\nOILS, MAINTEN...            ALL
# 13                                PROJECT DESCRIPTION           WARD
# 14  TOP UP ON REHABILITATION OF\nTEACHERS' STAFF H...        CHAMUKA
# 15  REHABILITATION OF 1X3 CLASSROOM\nBLOCK AT MOMB...        MUTENGA
# 16  REHABILITATION OF TEACHER’S STAFF\nHOUSE AT MO...        MUTENGA
# 17                    REHABILITATION OF KASAVASA ROAD  MISWA/MUTENGA
# 18  CONSTRUCTION OF VIP TOILET AT\nBOMBWE PRIMARY ...     MULUNGUSHI
#
#              ZONE  SECTOR OF\nPROJECT
# 0             ALL              HEALTH
# 1         CHAMUKA           TRANSPORT
# 2          LOMBWA              HEALTH
# 3         KABANGA              HEALTH
# 4                              HEALTH
# 5      MUPELEKESE              HEALTH
# 6         LUKOSHI              HEALTH
# 7          KAMANO              HEALTH
# 8       MONAGOMBE              HEALTH
# 9        MUSWISHI              HEALTH
# 10       MUSWISHI              HEALTH
# 11            ALL   ROAD\nDEVELOPMENT
# 12            ALL   ROAD\nDEVELOPMENT
# 13           ZONE  SECTOR OF\nPROJECT
# 14         KAPUTI           EDUCATION
# 15       MOMBOSHI           EDUCATION
# 16       MOMBOSHI           EDUCATION
# 17  MISWA/MUTENGA      INFRASTRUCTURE
# 18         BOMBWE           EDUCATION

# %%
df.to_csv("Chisamba2024_raw.csv" , index=False)
print("Raw dataset saved")
# Out:
# Raw dataset saved

# %%
import os

print(os.path.exists("Chisamba2024_raw.csv"))
print(os.path.getsize("Chisamba2024_raw.csv"))
# Out:
# True
# 2644
